# %%
# %reload_ext autoreload
# %autoreload 2

# %%
# %matplotlib notebook

# %%
from main import *
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\jiink\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# C:\Users\jiink\Anaconda3\lib\site-packages\gensim\utils.py:1197: UserWarning: detected Windows; aliasing chunkize to chunkize_serial
#   warnings.warn("detected Windows; aliasing chunkize to chunkize_serial")
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10447 entries, 0 to 10446
# Data columns (total 2 columns):
# message    10447 non-null object
# label      10447 non-null int64
# dtypes: int64(1), object(1)
# memory usage: 163.3+ KB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10447 entries, 0 to 10446
# Data columns (total 2 columns):
# message    10447 non-null object
# label      10447 non-null int64
# dtypes: int64(1), object(1)
# memory usage: 163.3+ KB
# ...

# %%
model = train(x_train, y_train, x_test, y_test)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
main_func(model)
# Out:
# Enter text to analyze, or press q to quit
# I love my dog
# You seem perfectly fine!
#
# Enter text to analyze, or press q to quit
# I want to sleep forever
# Oof, seems like you may have depression. If you ever start having dark thoughts, I suggest you seek help and/or call 1-800-273-8255.
#
# Enter text to analyze, or press q to quit
# kefefefe
# The word(s) in this text could not be analyzed :(
# Please try again
#
# Enter text to analyze, or press q to quit
# so sad today
# You seem perfectly fine!
#
# Enter text to analyze, or press q to quit
# I want to sleep forever, I don't want to live anymore
# Oof, seems like you may have depression. If you ever start having dark thoughts, I suggest you seek help and/or call 1-800-273-8255.
#
# Enter text to analyze, or press q to quit
# I am pulling all the troopsout of iran
# You seem perfectly fine!
#
# Enter text to analyze, or press q to quit
# this is a really cool project
# You seem perfectly fine!
#
# ...
